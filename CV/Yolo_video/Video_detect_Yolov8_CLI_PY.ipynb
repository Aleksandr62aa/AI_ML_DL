# %% [markdown]
# **Detecting objects in video and real-time using the neural network YOLOv8m**

# %%
# Connecting google drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# Setup YOLO using Python
# !pip install ultralytics
from ultralytics import YOLO

# Setup YOLO using CLI
# !pip install ultralytics -q

import torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.5/644.5 kB 9.8 MB/s eta 0:00:00
# ...

# %%
# load and predict model using Python
model = YOLO("yolov8m.pt")
results = model('/content/gdrive/MyDrive/CV/video.mp4', save=True)

# load and predict model using CLI
# !yolo detect predict model=yolov8m.pt source="vid.mp4"
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 195MB/s]
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/327) /content/gdrive/MyDrive/CV/video.mp4: 384x640 6 persons, 2 bicycles, 6 cars, 1 motorcycle, 3 buss, 1 backpack, 1 handbag, 75.7ms
# video 1/1 (2/327) /content/gdrive/MyDrive/CV/video.mp4: 384x640 5 persons, 2 bicycles, 8 cars, 1 motorcycle, 1 bus, 2 trucks, 1 traffic light, 1 backpack, 1 handbag, 26.1ms
# ...

# %%
# convert avi -> mp4
# !ffmpeg -i /content/runs/detect/predict/video.avi output.mp4

# !ffmpeg -i {'/content/runs/detect/predict2/vid.avi'} -vcodec libx264 {finel.mp4}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# load file mp4
from IPython.display import HTML
from base64 import b64encode

mp4 = open('output.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %%
# video
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
