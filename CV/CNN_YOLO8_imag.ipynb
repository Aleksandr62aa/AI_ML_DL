# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleksandr62aa/AI_ML_DL/blob/main/CNN_YOLO8_imag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Detecting objects in images using the  neural network YOLOv8**
#
# The YOLOv8 neural network can be used to solve problems of classification, object detection and image segmentation.
#
# ![image.png](data:image/png;base64,...)
#
# **Transfer Learning**

# %% [markdown]
# **Easy-to-use finetuned YOLOv8 models**

# %%
# Setup YOLO
# !pip install ultralytics
from ultralytics import YOLO

import torch

# %%
# load model
model = YOLO("yolov8m.pt")

# %%
# set image
image = "cat_dog.jpg"

# perform inference
results = model.predict(image)

result = results[0]
len(result.boxes)
# Out:
# image 1/1 /content/cat_dog.jpg: 448x640 1 cat, 1 dog, 1121.7ms
# Speed: 3.6ms preprocess, 1121.7ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 2

# %%
# parse results
for box in result.boxes:
  class_id = result.names[box.cls[0].item()]
  cords = box.xyxy[0].tolist()
  cords = [round(x) for x in cords]
  conf = round(box.conf[0].item(), 2)
  print("Object type:", class_id)
  print("Coordinates:", cords)
  print("Probability:", conf)
  print("---")
# Out:
# Object type: dog
# Coordinates: [261, 94, 461, 314]
# Probability: 0.94
# ---
# Object type: cat
# Coordinates: [140, 170, 256, 315]
# Probability: 0.91
# ---

# %%
# show results on image
from PIL import Image
Image.fromarray(result.plot()[:,:,::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=612x415>

# %%
# set image
image = 'https://ultralytics.com/images/zidane.jpg'

# perform inference
results = model.predict(image)

result = results[0]
len(result.boxes)
# Out:
# ...
# 100%|██████████| 165k/165k [00:00<00:00, 4.91MB/s]
# image 1/1 /content/zidane.jpg: 384x640 4 persons, 2 ties, 1289.7ms
# Speed: 2.5ms preprocess, 1289.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 6

# %%
# parse results
for box in result.boxes:
  class_id = result.names[box.cls[0].item()]
  cords = box.xyxy[0].tolist()
  cords = [round(x) for x in cords]
  conf = round(box.conf[0].item(), 2)
  print("Object type:", class_id)
  print("Coordinates:", cords)
  print("Probability:", conf)
  print("---")
# Out:
# Object type: person
# Coordinates: [120, 198, 1120, 712]
# Probability: 0.95
# ---
# Object type: person
# Coordinates: [746, 41, 1139, 711]
# Probability: 0.92
# ---
# Object type: tie
# Coordinates: [435, 437, 525, 717]
# Probability: 0.83
# ---
# Object type: tie
# Coordinates: [990, 316, 1132, 701]
# Probability: 0.3
# ---
# Object type: person
# Coordinates: [1100, 395, 1279, 715]
# Probability: 0.3
# ---
# Object type: person
# Coordinates: [0, 596, 124, 720]
# Probability: 0.26
# ---

# %%
# show results on image
from PIL import Image
Image.fromarray(result.plot()[:,:,::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
# set image
image = "man_cat_1.jpg"

# perform inference
results = model.predict(image)

result = results[0]
len(result.boxes)
# Out:
# image 1/1 /content/man_cat_1.jpg: 448x640 1 person, 1 cat, 1037.7ms
# Speed: 5.1ms preprocess, 1037.7ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 2

# %%
# parse results
for box in result.boxes:
  class_id = result.names[box.cls[0].item()]
  cords = box.xyxy[0].tolist()
  cords = [round(x) for x in cords]
  conf = round(box.conf[0].item(), 2)
  print("Object type:", class_id)
  print("Coordinates:", cords)
  print("Probability:", conf)
  print("---")
# Out:
# Object type: person
# Coordinates: [1, 1, 505, 409]
# Probability: 0.95
# ---
# Object type: cat
# Coordinates: [217, 189, 518, 361]
# Probability: 0.86
# ---

# %%
from PIL import Image
Image.fromarray(result.plot()[:,:,::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=612x415>
